# %% [markdown]
# <a href="https://colab.research.google.com/github/Birlinha/AlienHunting/blob/main/02_simplifiedAlienHunting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Escala Kardashev
# Essa é a escala de classificação de civilizações (projetada com a intenção de identificar e categorizar civilizações extra-terrestres):
#
# - TIPO 0 [🦠] - É capaz de utilizar toda a Enegia disponível em seu próprio organismo
# - TIPO 1 [🌎] - O organismo é capaz de utilizar toda a energia disponível no planeta em que vive
# - TIPO 2 [☀️] - Toda Energia disponível em seu sistema solar/estrela
# - TIPO 3 [🌌] - Energia de toda uma galáxia
# - TIPO 4 [⚛️] - E = mc², em múltiplas galáxias

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/rhFK5_Nx9xY?clip=Ugkx_FClgV4g75KAxU45UusDWJHSqmQioj8D&amp;clipt=ELm6Cxjr-Q4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/rhFK5_Nx9xY?clip=Ugkx_FClgV4g75KAxU45UusDWJHSqmQioj8D&amp;clipt=ELm6Cxjr-Q4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # Propostas de formas de Detecção de Civilizações
#
# Como encontrar uma civilização entre os Tipo 3 🌌 e Tipo 4 ⚛️
#
# - Detecção de ondas gravitacionais
#
#   1- porquê: civilizações avançadas podem estar interessadas na quantidade de energia armazenada em buracos negros, ou suas reações em forma de ondas gravitacionais.
#
#   2- como: identificação de ondas gravitacionais, análise de causa-raiz (o que causou a onda). Quando soubermos a fonte da onda, poderemos procurar por atividade alienigena 👽 por onde essa onda passa, através de dados visuais 🔭 ou outras formas 💹
#
#   3- dados: [Gravitational Wave Open Science Center](https://www.gw-openscience.org/eventapi/html/GWTC/)

# %%
# !pip install gwpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gwpy
#   Downloading gwpy-2.1.3-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 23.4 MB/s
# Collecting dqsegdb2
#   Downloading dqsegdb2-1.1.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gwpy) (1.4.1)
# Collecting gwdatafind
#   Downloading gwdatafind-1.1.1-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.2 MB/s
# Requirement already satisfied: astropy>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from gwpy) (4.3.1)
# Collecting ligotimegps>=1.2.1
#   Downloading ligotimegps-2.0.1-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: tqdm>=4.10.0 in /usr/local/lib/python3.7/dist-packages (from gwpy) (4.64.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from gwpy) (2.8.2)
# Requirement already satisfied: h5py>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from gwpy) (3.1.0)
# Collecting gwosc>=0.5.3
#   Downloading gwosc-0.6.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from gwpy) (1.21.6)
# Collecting matplotlib>=3.3.0
#   Downloading matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 50.5 MB/s
# Collecting ligo-segments>=1.0.0
#   Downloading ligo-segments-1.4.0.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 7.2 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from astropy>=3.0.0->gwpy) (4.11.4)
# Requirement already satisfied: pyerfa>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from astropy>=3.0.0->gwpy) (2.0.0.1)
# Requirement already satisfied: requests>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from gwosc>=0.5.3->gwpy) (2.23.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.7.0->gwpy) (1.5.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from ligo-segments>=1.0.0->gwpy) (1.15.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->gwpy) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      |████████████████████████████████| 930 kB 51.2 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->gwpy) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->gwpy) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->gwpy) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.0->gwpy) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.0->gwpy) (4.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->gwosc>=0.5.3->gwpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->gwosc>=0.5.3->gwpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->gwosc>=0.5.3->gwpy) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->gwosc>=0.5.3->gwpy) (3.0.4)
# Collecting igwn-auth-utils[requests]
#   Downloading igwn_auth_utils-0.2.2-py3-none-any.whl (20 kB)
# Collecting scitokens>=1.7.0
#   Downloading scitokens-1.7.0-py3-none-any.whl (23 kB)
# Collecting cryptography>=2.3
#   Downloading cryptography-37.0.2-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 29.9 MB/s
# Collecting safe-netrc>=1.0.0
#   Downloading safe_netrc-1.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.3->igwn-auth-utils[requests]->dqsegdb2->gwpy) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.3->igwn-auth-utils[requests]->dqsegdb2->gwpy) (2.21)
# Collecting PyJWT>=1.6.1
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy>=3.0.0->gwpy) (3.8.0)
# Building wheels for collected packages: ligo-segments
#   Building wheel for ligo-segments (setup.py) ... done
#   Created wheel for ligo-segments: filename=ligo_segments-1.4.0-cp37-cp37m-linux_x86_64.whl size=86640 sha256=521cb5322b24fcbd434d5e052db419e70befe54fd692b793e53a0205305a78c3
#   Stored in directory: /root/.cache/pip/wheels/09/f9/d4/129b3bb4458d50b56fdc8245ace7c8216d54865fe8d3aebc05
# Successfully built ligo-segments
# Installing collected packages: PyJWT, cryptography, scitokens, safe-netrc, igwn-auth-utils, ligo-segments, fonttools, matplotlib, ligotimegps, gwosc, gwdatafind, dqsegdb2, gwpy
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed PyJWT-2.4.0 cryptography-37.0.2 dqsegdb2-1.1.1 fonttools-4.33.3 gwdatafind-1.1.1 gwosc-0.6.1 gwpy-2.1.3 igwn-auth-utils-0.2.2 ligo-segments-1.4.0 ligotimegps-2.0.1 matplotlib-3.5.2 safe-netrc-1.0.0 scitokens-1.7.0

# %% [markdown]
# # Coding Time
#
# [GWOSC Workshop](https://www.gw-openscience.org/odw/odw2022)

# %%
from gwosc import datasets

# %%
datasets.api.fetch_allevents_json()
# Out:
# {'events': {'151008-v1': {'GPS': 1128348574.5,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 5.12,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '151008',
#    'far': 10.17,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/151008/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 8.8,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '151012.2-v1': {'GPS': 1128666662.2,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 2.01,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '151012.2',
#    'far': 8.56,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/151012.2/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.6,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '151116-v1': {'GPS': 1131748925.7,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 1.24,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '151116',
#    'far': 4.77,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/151116/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.0,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '161202-v1': {'GPS': 1164686041.9,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 1.54,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '161202',
#    'far': 6.0,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/161202/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 10.5,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '161217-v1': {'GPS': 1165994201.4,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 7.86,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '161217',
#    'far': 10.12,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/161217/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 10.7,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '170208-v1': {'GPS': 1170585583.8,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 7.39,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '170208',
#    'far': 11.18,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/170208/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 10.0,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '170219-v1': {'GPS': 1171548267.0,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 1.53,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '170219',
#    'far': 6.26,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/170219/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.6,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '170405-v1': {'GPS': 1175425510.7,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 1.44,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '170405',
#    'far': 4.55,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/170405/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.3,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '170412-v1': {'GPS': 1176047817.0,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 4.36,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '170412',
#    'far': 8.22,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/170412/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.7,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '170423-v1': {'GPS': 1176984663.0,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 1.17,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '170423',
#    'far': 6.47,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/170423/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 8.9,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '170616-v1': {'GPS': 1181677658.8,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 2.75,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '170616',
#    'far': 1.94,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/170616/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.1,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '170630-v1': {'GPS': 1182874645.8,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 0.9,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '170630',
#    'far': 10.46,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/170630/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.7,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '170705-v1': {'GPS': 1183279534.3,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 3.4,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '170705',
#    'far': 10.97,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/170705/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.3,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '170720-v1': {'GPS': 1184625889.8,
#    'catalog.shortName': 'GWTC-1-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': 5.96,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': 'M_sun',
#    'chirp_mass_upper': None,
#    'commonName': '170720',
#    'far': 10.75,
#    'far_lower': None,
#    'far_unit': 'yr^-1',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-1-marginal/170720/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 13.0,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/82H3-HH23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '190924_232654-v1': {'GPS': 1253402833.0,
#    'catalog.shortName': 'O3_IMBH_marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': '190924_232654',
#    'far': 0.4,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/O3_IMBH_marginal/190924_232654/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 13.03,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/O3_IMBH_marginal/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '191118_212859-v1': {'GPS': 1258147757.4,
#    'catalog.shortName': 'GWTC-3-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW191118_212859',
#    'far': 1.3,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-marginal/GW191118_212859/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.121,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': 0.0452,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/GWTC-3/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '191223_014159-v1': {'GPS': 1261100537.6,
#    'catalog.shortName': 'O3_IMBH_marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': '191223_014159',
#    'far': 0.46,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/O3_IMBH_marginal/191223_014159/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 14.19,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/O3_IMBH_marginal/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '191225_215715-v1': {'GPS': 1261346253.9,
#    'catalog.shortName': 'O3_IMBH_marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': '191225_215715',
#    'far': 0.47,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/O3_IMBH_marginal/191225_215715/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 17.88,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/O3_IMBH_marginal/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '200114_020818-v1': {'GPS': 1263002916.2,
#    'catalog.shortName': 'O3_IMBH_marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': '200114_020818',
#    'far': 0.058,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/O3_IMBH_marginal/200114_020818/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 14.5,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/O3_IMBH_marginal/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '200121_031748-v1': {'GPS': 1263611886.9,
#    'catalog.shortName': 'GWTC-3-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': '200121_031748',
#    'far': 1.1,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-marginal/200121_031748/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 10.69,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': 0.23,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/GWTC-3/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '200201_203549-v1': {'GPS': 1264624567.0,
#    'catalog.shortName': 'GWTC-3-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW200201_203549',
#    'far': 1.4,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-marginal/GW200201_203549/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.046,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': 0.116,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/GWTC-3/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '200214_224526-v1': {'GPS': 1265755544.5,
#    'catalog.shortName': 'O3_IMBH_marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': '200214_224526',
#    'far': 0.1314,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/O3_IMBH_marginal/200214_224526/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 13.1,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/O3_IMBH_marginal/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '200214_224526-v2': {'GPS': 1265755544.5,
#    'catalog.shortName': 'GWTC-3-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': '200214_224526',
#    'far': 0.131444,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-marginal/200214_224526/v2',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 13.133,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': 0.9095,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/GWTC-3/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 2},
#   '200219_201407-v1': {'GPS': 1266178465.9,
#    'catalog.shortName': 'GWTC-3-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': '200219_201407',
#    'far': 0.22,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-marginal/200219_201407/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 13.59,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': 0.481,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/GWTC-3/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   '200311_103121-v1': {'GPS': 1267957899.7,
#    'catalog.shortName': 'GWTC-3-marginal',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW200311_103121',
#    'far': 1.3,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-marginal/GW200311_103121/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': 9.2,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': None,
#    'p_astro': 0.194,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': '/GWTC-3/',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   'GRB051103-v1': {'GPS': 815043278.0,
#    'catalog.shortName': 'Initial_LIGO_Virgo',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GRB051103',
#    'far': None,
#    'far_lower': None,
#    'far_unit': None,
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/Initial_LIGO_Virgo/GRB051103/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': None,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': None,
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://www.ligo.org/scientists/GRB051103/index.php',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   'GW150914-v1': {'GPS': 1126259462.4,
#    'catalog.shortName': 'O1_O2-Preliminary',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW150914',
#    'far': None,
#    'far_lower': None,
#    'far_unit': None,
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/O1_O2-Preliminary/GW150914/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': None,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': None,
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://doi.org/10.7935/K5MW2F23',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1},
#   'GW150914-v2': {'GPS': 1126259462.4,
#    'catalog.shortName': 'O1_O2-Preliminary',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW150914',
#    'far': None,
#    'far_lower': None,
#    'far_unit': None,
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/O1_O2-Preliminary/GW150914/v2',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': None,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': None,
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
# ...
#    'p_astro_upper': None,
#    'redshift': 0.66,
#    'redshift_lower': -0.31,
#    'redshift_unit': '',
#    'redshift_upper': 0.36,
#    'reference': '/GWTC-3/',
#    'total_mass_source': 67.0,
#    'total_mass_source_lower': -12.0,
#    'total_mass_source_unit': '',
#    'total_mass_source_upper': 17.0,
#    'version': 1},
#   'GW200224_222234-v1': {'GPS': 1266618172.4,
#    'catalog.shortName': 'GWTC-3-confident',
#    'chi_eff': 0.1,
#    'chi_eff_lower': -0.15,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.15,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': 31.1,
#    'chirp_mass_source_lower': -2.6,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 3.2,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW200224_222234',
#    'far': 1e-05,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 68.6,
#    'final_mass_source_lower': -4.7,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 6.6,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200224_222234/v1',
#    'luminosity_distance': 1710.0,
#    'luminosity_distance_lower': -640.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 490.0,
#    'mass_1_source': 40.0,
#    'mass_1_source_lower': -4.5,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 6.9,
#    'mass_2_source': 32.5,
#    'mass_2_source_lower': -7.2,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 5.0,
#    'network_matched_filter_snr': 20.0,
#    'network_matched_filter_snr_lower': -0.2,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': 0.2,
#    'p_astro': 0.99,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': 0.32,
#    'redshift_lower': -0.11,
#    'redshift_unit': '',
#    'redshift_upper': 0.08,
#    'reference': '/GWTC-3/',
#    'total_mass_source': 72.2,
#    'total_mass_source_lower': -5.1,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 7.2,
#    'version': 1},
#   'GW200225_060421-v1': {'GPS': 1266645879.3,
#    'catalog.shortName': 'GWTC-3-confident',
#    'chi_eff': -0.12,
#    'chi_eff_lower': -0.28,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.17,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': 14.2,
#    'chirp_mass_source_lower': -1.4,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 1.5,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW200225_060421',
#    'far': 1.1e-05,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 32.1,
#    'final_mass_source_lower': -2.8,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 3.5,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200225_060421/v1',
#    'luminosity_distance': 1150.0,
#    'luminosity_distance_lower': -530.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 510.0,
#    'mass_1_source': 19.3,
#    'mass_1_source_lower': -3.0,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 5.0,
#    'mass_2_source': 14.0,
#    'mass_2_source_lower': -3.5,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 2.8,
#    'network_matched_filter_snr': 12.5,
#    'network_matched_filter_snr_lower': -0.4,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': 0.3,
#    'p_astro': 0.99,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': 0.22,
#    'redshift_lower': -0.1,
#    'redshift_unit': '',
#    'redshift_upper': 0.09,
#    'reference': '/GWTC-3/',
#    'total_mass_source': 33.5,
#    'total_mass_source_lower': -3.0,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 3.6,
#    'version': 1},
#   'GW200302_015811-v1': {'GPS': 1267149509.5,
#    'catalog.shortName': 'GWTC-3-confident',
#    'chi_eff': 0.01,
#    'chi_eff_lower': -0.26,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.25,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': 23.4,
#    'chirp_mass_source_lower': -3.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 4.7,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW200302_015811',
#    'far': 0.11,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 55.5,
#    'final_mass_source_lower': -6.6,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 8.9,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200302_015811/v1',
#    'luminosity_distance': 1480.0,
#    'luminosity_distance_lower': -700.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 1020.0,
#    'mass_1_source': 37.8,
#    'mass_1_source_lower': -8.5,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 8.7,
#    'mass_2_source': 20.0,
#    'mass_2_source_lower': -5.7,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 8.1,
#    'network_matched_filter_snr': 10.8,
#    'network_matched_filter_snr_lower': -0.4,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': 0.3,
#    'p_astro': 0.90643,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': 0.28,
#    'redshift_lower': -0.12,
#    'redshift_unit': '',
#    'redshift_upper': 0.16,
#    'reference': '/GWTC-3/',
#    'total_mass_source': 57.8,
#    'total_mass_source_lower': -6.9,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 9.6,
#    'version': 1},
#   'GW200306_093714-v1': {'GPS': 1267522652.1,
#    'catalog.shortName': 'GWTC-3-confident',
#    'chi_eff': 0.32,
#    'chi_eff_lower': -0.46,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.28,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': 17.5,
#    'chirp_mass_source_lower': -3.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 3.5,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW200306_093714',
#    'far': 24.0,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 41.7,
#    'final_mass_source_lower': -6.9,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 12.3,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200306_093714/v1',
#    'luminosity_distance': 2100.0,
#    'luminosity_distance_lower': -1100.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 1700.0,
#    'mass_1_source': 28.3,
#    'mass_1_source_lower': -7.7,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 17.1,
#    'mass_2_source': 14.8,
#    'mass_2_source_lower': -6.4,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 6.5,
#    'network_matched_filter_snr': 7.8,
#    'network_matched_filter_snr_lower': -0.6,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': 0.4,
#    'p_astro': 0.24004,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': 0.38,
#    'redshift_lower': -0.18,
#    'redshift_unit': '',
#    'redshift_upper': 0.24,
#    'reference': '/GWTC-3/',
#    'total_mass_source': 43.9,
#    'total_mass_source_lower': -7.5,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 11.8,
#    'version': 1},
#   'GW200308_173609-v1': {'GPS': 1267724187.7,
#    'catalog.shortName': 'GWTC-3-confident',
#    'chi_eff': 0.65,
#    'chi_eff_lower': -0.21,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.17,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': 19.0,
#    'chirp_mass_source_lower': -2.8,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 4.8,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW200308_173609',
#    'far': 2.4,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 47.4,
#    'final_mass_source_lower': -7.7,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 11.1,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200308_173609/v1',
#    'luminosity_distance': 5400.0,
#    'luminosity_distance_lower': -2600.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 2700.0,
#    'mass_1_source': 36.4,
#    'mass_1_source_lower': -9.6,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 11.2,
#    'mass_2_source': 13.8,
#    'mass_2_source_lower': -3.3,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 7.2,
#    'network_matched_filter_snr': 7.1,
#    'network_matched_filter_snr_lower': -0.5,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': 0.5,
#    'p_astro': 0.8566,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': 0.83,
#    'redshift_lower': -0.35,
#    'redshift_unit': '',
#    'redshift_upper': 0.32,
#    'reference': '/GWTC-3/',
#    'total_mass_source': 50.6,
#    'total_mass_source_lower': -8.5,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 10.9,
#    'version': 1},
#   'GW200311_115853-v1': {'GPS': 1267963151.3,
#    'catalog.shortName': 'GWTC-3-confident',
#    'chi_eff': -0.02,
#    'chi_eff_lower': -0.2,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.16,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': 26.6,
#    'chirp_mass_source_lower': -2.0,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 2.4,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW200311_115853',
#    'far': 1e-05,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 59.0,
#    'final_mass_source_lower': -3.9,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 4.8,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200311_115853/v1',
#    'luminosity_distance': 1170.0,
#    'luminosity_distance_lower': -400.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 280.0,
#    'mass_1_source': 34.2,
#    'mass_1_source_lower': -3.8,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 6.4,
#    'mass_2_source': 27.7,
#    'mass_2_source_lower': -5.9,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 4.1,
#    'network_matched_filter_snr': 17.8,
#    'network_matched_filter_snr_lower': -0.2,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': 0.2,
#    'p_astro': 0.99,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': 0.23,
#    'redshift_lower': -0.07,
#    'redshift_unit': '',
#    'redshift_upper': 0.05,
#    'reference': '/GWTC-3/',
#    'total_mass_source': 61.9,
#    'total_mass_source_lower': -4.2,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 5.3,
#    'version': 1},
#   'GW200316_215756-v1': {'GPS': 1268431094.1,
#    'catalog.shortName': 'GWTC-3-confident',
#    'chi_eff': 0.13,
#    'chi_eff_lower': -0.1,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.27,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': 8.75,
#    'chirp_mass_source_lower': -0.55,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 0.62,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW200316_215756',
#    'far': 1e-05,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 20.2,
#    'final_mass_source_lower': -1.9,
#    'final_mass_source_unit': 'M_sun',
#    'final_mass_source_upper': 7.4,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200316_215756/v1',
#    'luminosity_distance': 1120.0,
#    'luminosity_distance_lower': -440.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 470.0,
#    'mass_1_source': 13.1,
#    'mass_1_source_lower': -2.9,
#    'mass_1_source_unit': 'M_sun',
#    'mass_1_source_upper': 10.2,
#    'mass_2_source': 7.8,
#    'mass_2_source_lower': -2.9,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 1.9,
#    'network_matched_filter_snr': 10.3,
#    'network_matched_filter_snr_lower': -0.7,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': 0.4,
#    'p_astro': 0.99,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': 0.22,
#    'redshift_lower': -0.08,
#    'redshift_unit': '',
#    'redshift_upper': 0.08,
#    'reference': '/GWTC-3/',
#    'total_mass_source': 21.2,
#    'total_mass_source_lower': -2.0,
#    'total_mass_source_unit': 'M_sun',
#    'total_mass_source_upper': 7.2,
#    'version': 1},
#   'GW200322_091133-v1': {'GPS': 1268903511.3,
#    'catalog.shortName': 'GWTC-3-confident',
#    'chi_eff': 0.24,
#    'chi_eff_lower': -0.51,
#    'chi_eff_unit': '',
#    'chi_eff_upper': 0.45,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': 15.5,
#    'chirp_mass_source_lower': -3.7,
#    'chirp_mass_source_unit': 'M_sun',
#    'chirp_mass_source_upper': 15.7,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'GW200322_091133',
#    'far': 140.0,
#    'far_lower': None,
#    'far_unit': '1/yr',
#    'far_upper': None,
#    'final_mass_source': 53.0,
#    'final_mass_source_lower': -26.0,
#    'final_mass_source_unit': '',
#    'final_mass_source_upper': 38.0,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/GWTC-3-confident/GW200322_091133/v1',
#    'luminosity_distance': 3600.0,
#    'luminosity_distance_lower': -2000.0,
#    'luminosity_distance_unit': 'Mpc',
#    'luminosity_distance_upper': 7000.0,
#    'mass_1_source': 34.0,
#    'mass_1_source_lower': -18.0,
#    'mass_1_source_unit': '',
#    'mass_1_source_upper': 48.0,
#    'mass_2_source': 14.0,
#    'mass_2_source_lower': -8.7,
#    'mass_2_source_unit': 'M_sun',
#    'mass_2_source_upper': 16.8,
#    'network_matched_filter_snr': 6.0,
#    'network_matched_filter_snr_lower': -1.2,
#    'network_matched_filter_snr_unit': '',
#    'network_matched_filter_snr_upper': 1.7,
#    'p_astro': 0.077572,
#    'p_astro_lower': None,
#    'p_astro_unit': '',
#    'p_astro_upper': None,
#    'redshift': 0.6,
#    'redshift_lower': -0.3,
#    'redshift_unit': '',
#    'redshift_upper': 0.84,
#    'reference': '/GWTC-3/',
#    'total_mass_source': 55.0,
#    'total_mass_source_lower': -27.0,
#    'total_mass_source_unit': '',
#    'total_mass_source_upper': 37.0,
#    'version': 1},
#   'blind_injection-v1': {'GPS': 968654557.9,
#    'catalog.shortName': 'Initial_LIGO_Virgo',
#    'chi_eff': None,
#    'chi_eff_lower': None,
#    'chi_eff_unit': None,
#    'chi_eff_upper': None,
#    'chirp_mass': None,
#    'chirp_mass_lower': None,
#    'chirp_mass_source': None,
#    'chirp_mass_source_lower': None,
#    'chirp_mass_source_unit': None,
#    'chirp_mass_source_upper': None,
#    'chirp_mass_unit': None,
#    'chirp_mass_upper': None,
#    'commonName': 'blind_injection',
#    'far': None,
#    'far_lower': None,
#    'far_unit': None,
#    'far_upper': None,
#    'final_mass_source': None,
#    'final_mass_source_lower': None,
#    'final_mass_source_unit': None,
#    'final_mass_source_upper': None,
#    'jsonurl': 'https://www.gw-openscience.org/eventapi/json/Initial_LIGO_Virgo/blind_injection/v1',
#    'luminosity_distance': None,
#    'luminosity_distance_lower': None,
#    'luminosity_distance_unit': None,
#    'luminosity_distance_upper': None,
#    'mass_1_source': None,
#    'mass_1_source_lower': None,
#    'mass_1_source_unit': None,
#    'mass_1_source_upper': None,
#    'mass_2_source': None,
#    'mass_2_source_lower': None,
#    'mass_2_source_unit': None,
#    'mass_2_source_upper': None,
#    'network_matched_filter_snr': None,
#    'network_matched_filter_snr_lower': None,
#    'network_matched_filter_snr_unit': None,
#    'network_matched_filter_snr_upper': None,
#    'p_astro': None,
#    'p_astro_lower': None,
#    'p_astro_unit': None,
#    'p_astro_upper': None,
#    'redshift': None,
#    'redshift_lower': None,
#    'redshift_unit': None,
#    'redshift_upper': None,
#    'reference': 'https://www.ligo.org/scientists/GW100916/index.php',
#    'total_mass_source': None,
#    'total_mass_source_lower': None,
#    'total_mass_source_unit': None,
#    'total_mass_source_upper': None,
#    'version': 1}}}
