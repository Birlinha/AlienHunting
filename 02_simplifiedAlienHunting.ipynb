# %% [markdown]
# <a href="https://colab.research.google.com/github/Birlinha/AlienHunting/blob/main/02_simplifiedAlienHunting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 👽 Quem está pronto para um **Encontro Imediato** 🛸?
#
# Hoje vamos analisar imagens de satélite, em busca de atividade alienígena
#
# Para realizar isso, antes precisamos entender um pouco sobre a Escala de Kardashev. Ela serve como régua para aferição do tamanho e influência de uma civilização sobre os planetas e galáxias em que habitam

# %%
# %%html
# <img src="https://danhairfield.files.wordpress.com/2014/05/paul.jpg" style="width:100%;height:720px;      object-fit:cover;object-position:0 30%;">
# Out:
# <img src="https://danhairfield.files.wordpress.com/2014/05/paul.jpg" style="width:100%;height:720px;      object-fit:cover;object-position:0 30%;">

# %% [markdown]
# # Escala Kardashev
# Essa é a escala de classificação de civilizações (projetada com a intenção de identificar e categorizar civilizações extra-terrestres):
#
# - TIPO 0 [🦠] - É capaz de utilizar toda a Enegia disponível em seu próprio organismo
# - TIPO 1 [🌎] - O organismo é capaz de utilizar toda a energia disponível no planeta em que vive
# - TIPO 2 [☀️] - Toda Energia disponível em seu sistema solar/estrela
# - TIPO 3 [🌌] - Energia de toda uma galáxia
# - TIPO 4 [⚛️] - E = mc², em múltiplas galáxias

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/rhFK5_Nx9xY?clip=Ugkx_FClgV4g75KAxU45UusDWJHSqmQioj8D&amp;clipt=ELm6Cxjr-Q4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/rhFK5_Nx9xY?clip=Ugkx_FClgV4g75KAxU45UusDWJHSqmQioj8D&amp;clipt=ELm6Cxjr-Q4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # Propostas de formas de Detecção de Civilizações
#
# Como encontrar uma civilização entre os Tipo 3 🌌 e Tipo 4 ⚛️
#
# - Detecção de ondas gravitacionais
#
#   1- porquê: civilizações avançadas podem estar interessadas na quantidade de energia armazenada em buracos negros, ou suas reações em forma de ondas gravitacionais.
#
#   2- como: identificação de ondas gravitacionais, análise de causa-raiz (o que causou a onda). Quando soubermos a fonte da onda, poderemos procurar por atividade alienigena 👽 por onde essa onda passa, através de dados visuais 🔭 ou outras formas 💹
#
#   3- dados: [Gravitational Wave Open Science Center](https://www.gw-openscience.org/eventapi/html/GWTC/)

# %% [markdown]
# # Coding Time
#
# [GWOSC Workshop](https://www.gw-openscience.org/odw/odw2022)
#
# ## Diretórios

# %%
def criar_pastas():
  from os import path
  from os import mkdir

  if path.exists('./data') == False:
    mkdir('./data')

  return 'pastas foram criadas'

# %%
criar_pastas()
# Out:
# 'pastas foram criadas'

# %% [markdown]
# ## Data Load

# %%
def import_file(google_drive_folder_id):
  from os import path
  from gdown import download

  if path.exists('./data/LIGO.csv') == False:
    download('https://drive.google.com/uc?id={}'.format(google_drive_folder_id),output="./data/LIGO.csv", quiet=0)

# %%
import_file('1_ACZvMZE3uu5V4Ib8tBrwCkPNr1zjTSw')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_ACZvMZE3uu5V4Ib8tBrwCkPNr1zjTSw
# To: /content/data/LIGO.csv
# 100%|██████████| 29.8k/29.8k [00:00<00:00, 8.52MB/s]

# %% [markdown]
# ## Data Read

# %%
def read_data():
  import pandas as pd

  df = pd.read_csv('./data/LIGO.csv')
  return df

# %%
df = read_data()

# %%
df.head()
# Out:
#             id commonName  version catalog.shortName           GPS  \
# 0  GW150914-v3   GW150914        3  GWTC-1-confident  1.126259e+09
# 1  GW151012-v3   GW151012        3  GWTC-1-confident  1.128679e+09
# 2  GW151226-v2   GW151226        2  GWTC-1-confident  1.135136e+09
# 3  GW170104-v2   GW170104        2  GWTC-1-confident  1.167560e+09
# 4  GW170608-v3   GW170608        3  GWTC-1-confident  1.180922e+09
#
#                            reference  \
# 0  https://doi.org/10.7935/82H3-HH23
# 1  https://doi.org/10.7935/82H3-HH23
# 2  https://doi.org/10.7935/82H3-HH23
# 3  https://doi.org/10.7935/82H3-HH23
# 4  https://doi.org/10.7935/82H3-HH23
#
#                                              jsonurl  mass_1_source  \
# 0  https://www.gw-openscience.org/eventapi/json/G...           35.6
# 1  https://www.gw-openscience.org/eventapi/json/G...           23.2
# 2  https://www.gw-openscience.org/eventapi/json/G...           13.7
# 3  https://www.gw-openscience.org/eventapi/json/G...           30.8
# 4  https://www.gw-openscience.org/eventapi/json/G...           11.0
#
#    mass_1_source_lower  mass_1_source_upper  ...  redshift_upper  \
# 0                 -3.1                  4.7  ...            0.03
# 1                 -5.5                 14.9  ...            0.09
# 2                 -3.2                  8.8  ...            0.04
# 3                 -5.6                  7.3  ...            0.08
# 4                 -1.7                  5.5  ...            0.02
#
#             far  far_lower  far_upper  p_astro  p_astro_lower  p_astro_upper  \
# 0  1.000000e-07        NaN        NaN      1.0            NaN            NaN
# 1  7.920000e-03        NaN        NaN      1.0            NaN            NaN
# 2  1.000000e-07        NaN        NaN      1.0            NaN            NaN
# 3  1.000000e-07        NaN        NaN      1.0            NaN            NaN
# 4  1.000000e-07        NaN        NaN      1.0            NaN            NaN
#
#    final_mass_source  final_mass_source_lower  final_mass_source_upper
# 0               63.1                     -3.0                      3.4
# 1               35.6                     -3.8                     10.8
# 2               20.5                     -1.5                      6.4
# 3               48.9                     -4.0                      5.1
# 4               17.8                     -0.7                      3.4
#
# [5 rows x 43 columns]

# %%
df = df.drop(columns=["id","version","reference","jsonurl"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 39 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   commonName                        93 non-null     object
#  1   catalog.shortName                 93 non-null     object
#  2   GPS                               93 non-null     float64
#  3   mass_1_source                     90 non-null     float64
#  4   mass_1_source_lower               90 non-null     float64
#  5   mass_1_source_upper               90 non-null     float64
#  6   mass_2_source                     90 non-null     float64
#  7   mass_2_source_lower               90 non-null     float64
#  8   mass_2_source_upper               90 non-null     float64
#  9   network_matched_filter_snr        93 non-null     float64
#  10  network_matched_filter_snr_lower  43 non-null     float64
#  11  network_matched_filter_snr_upper  43 non-null     float64
#  12  luminosity_distance               90 non-null     float64
#  13  luminosity_distance_lower         90 non-null     float64
#  14  luminosity_distance_upper         90 non-null     float64
#  15  chi_eff                           90 non-null     float64
#  16  chi_eff_lower                     90 non-null     float64
#  17  chi_eff_upper                     90 non-null     float64
#  18  total_mass_source                 79 non-null     float64
#  19  total_mass_source_lower           79 non-null     float64
#  20  total_mass_source_upper           79 non-null     float64
#  21  chirp_mass_source                 90 non-null     float64
#  22  chirp_mass_source_lower           90 non-null     float64
#  23  chirp_mass_source_upper           90 non-null     float64
#  24  chirp_mass                        36 non-null     float64
#  25  chirp_mass_lower                  36 non-null     float64
#  26  chirp_mass_upper                  36 non-null     float64
#  27  redshift                          90 non-null     float64
#  28  redshift_lower                    90 non-null     float64
#  29  redshift_upper                    90 non-null     float64
#  30  far                               93 non-null     float64
#  31  far_lower                         0 non-null      float64
#  32  far_upper                         0 non-null      float64
#  33  p_astro                           90 non-null     float64
#  34  p_astro_lower                     0 non-null      float64
#  35  p_astro_upper                     0 non-null      float64
#  36  final_mass_source                 89 non-null     float64
#  37  final_mass_source_lower           88 non-null     float64
#  38  final_mass_source_upper           88 non-null     float64
# dtypes: float64(37), object(2)
# memory usage: 28.5+ KB

# %%
df
# Out:
#          commonName catalog.shortName           GPS  mass_1_source  \
# 0          GW150914  GWTC-1-confident  1.126259e+09           35.6
# 1          GW151012  GWTC-1-confident  1.128679e+09           23.2
# 2          GW151226  GWTC-1-confident  1.135136e+09           13.7
# 3          GW170104  GWTC-1-confident  1.167560e+09           30.8
# 4          GW170608  GWTC-1-confident  1.180922e+09           11.0
# ..              ...               ...           ...            ...
# 88  GW200306_093714  GWTC-3-confident  1.267523e+09           28.3
# 89  GW200308_173609  GWTC-3-confident  1.267724e+09           36.4
# 90  GW200311_115853  GWTC-3-confident  1.267963e+09           34.2
# 91  GW200316_215756  GWTC-3-confident  1.268431e+09           13.1
# 92  GW200322_091133  GWTC-3-confident  1.268904e+09           34.0
#
#     mass_1_source_lower  mass_1_source_upper  mass_2_source  \
# 0                  -3.1                  4.7           30.6
# 1                  -5.5                 14.9           13.6
# 2                  -3.2                  8.8            7.7
# 3                  -5.6                  7.3           20.0
# 4                  -1.7                  5.5            7.6
# ..                  ...                  ...            ...
# 88                 -7.7                 17.1           14.8
# 89                 -9.6                 11.2           13.8
# 90                 -3.8                  6.4           27.7
# 91                 -2.9                 10.2            7.8
# 92                -18.0                 48.0           14.0
#
#     mass_2_source_lower  mass_2_source_upper  network_matched_filter_snr  ...  \
# 0                  -4.4                  3.0                        24.4  ...
# 1                  -4.8                  4.1                        10.0  ...
# 2                  -2.5                  2.2                        13.1  ...
# 3                  -4.6                  4.9                        13.0  ...
# 4                  -2.2                  1.4                        14.9  ...
# ..                  ...                  ...                         ...  ...
# 88                 -6.4                  6.5                         7.8  ...
# 89                 -3.3                  7.2                         7.1  ...
# 90                 -5.9                  4.1                        17.8  ...
# 91                 -2.9                  1.9                        10.3  ...
# 92                 -8.7                 16.8                         6.0  ...
#
#     redshift_upper           far  far_lower  far_upper   p_astro  \
# 0             0.03  1.000000e-07        NaN        NaN  1.000000
# 1             0.09  7.920000e-03        NaN        NaN  1.000000
# 2             0.04  1.000000e-07        NaN        NaN  1.000000
# 3             0.08  1.000000e-07        NaN        NaN  1.000000
# 4             0.02  1.000000e-07        NaN        NaN  1.000000
# ..             ...           ...        ...        ...       ...
# 88            0.24  2.400000e+01        NaN        NaN  0.240040
# 89            0.32  2.400000e+00        NaN        NaN  0.856600
# 90            0.05  1.000000e-05        NaN        NaN  0.990000
# 91            0.08  1.000000e-05        NaN        NaN  0.990000
# 92            0.84  1.400000e+02        NaN        NaN  0.077572
#
#     p_astro_lower  p_astro_upper  final_mass_source  final_mass_source_lower  \
# 0             NaN            NaN               63.1                     -3.0
# 1             NaN            NaN               35.6                     -3.8
# 2             NaN            NaN               20.5                     -1.5
# 3             NaN            NaN               48.9                     -4.0
# 4             NaN            NaN               17.8                     -0.7
# ..            ...            ...                ...                      ...
# 88            NaN            NaN               41.7                     -6.9
# 89            NaN            NaN               47.4                     -7.7
# 90            NaN            NaN               59.0                     -3.9
# 91            NaN            NaN               20.2                     -1.9
# 92            NaN            NaN               53.0                    -26.0
#
#     final_mass_source_upper
# 0                       3.4
# 1                      10.8
# 2                       6.4
# 3                       5.1
# 4                       3.4
# ..                      ...
# 88                     12.3
# 89                     11.1
# 90                      4.8
# 91                      7.4
# 92                     38.0
#
# [93 rows x 39 columns]
